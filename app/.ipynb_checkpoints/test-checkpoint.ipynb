# %%
import requests

# %%
url='http://127.0.0.1:8000/Net_disk_api/signup'
data={'usrName':  'test_account'}
web=requests.post(url,data)
web.json()
# Out:
# {'status': True}

# %%
url='http://127.0.0.1:8000/Net_disk_api/delaccount'
data={'usrName':  'test_account'}
web=requests.post(url,data)
web.json()
# Out:
# {'status': 'True'}

# %%
path=r'C:\Users\root\Desktop\工程居间合同.docx'

# %%
content.decode('base64')

# %%
codecs.decode()

# %%
cookies = requests.utils.dict_from_cookiejar(web.cookies)
print(cookies)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-59255a1f9138> in <module>
# ----> 1 cookies = requests.utils.dict_from_cookiejar(web.cookies)
#       2 print(cookies)
#
# NameError: name 'requests' is not defined

# %%
print(len(content))

file={'file':open(path,'rb')}
url_s='http://127.0.0.1:8000/Net_disk_api/upload'
params={
        'fileName':'test.docx',
        'path':'test.docx',
        't_batchs':1,
        'cur_batch':0,
        'file_size':len(content)
       }
rp=requests.post(url_s,params,cookies=cookies,files=file)
# Out:
# 16775

# %%
rp.json()
# Out:
# {'status': True}

# %%
content.decode('utf-8')

# %%
import os
import math
class package:
    def __init__(self):
        self.url_create_usr='http://127.0.0.1:8000/Net_disk_api/signup'
        self.url_del_usr='http://127.0.0.1:8000/Net_disk_api/delaccount'
        self.url_upload='http://127.0.0.1:8000/Net_disk_api/upload'
    def preprocess_infor_file(self,path,chunk):
        file_size=os.path.getsize(path)
        set_chunks=math.ceil(file_size/chunk)
        return file_size,set_chunks
    def upload_by_batch(self,path,fileName,tar_Path,chunks,chunk_size,file_size):
        params={
        'fileName':fileName,
        'path':tar_Path,
        't_batchs':chunks,
        'file_size':file_size
       }
        def file_iterator(file_name, chunk_size=chunk_size):
            with open(path,'rb') as f:
                while True:
                    c = f.read(chunk_size)
                    if c:
                        yield c
                    else:
                        break
        file={}
        for index,item in enumerate(file_iterator(path),0):
            file['file']=item
            params['cur_batch']=index
            web=requests.post(self.url_upload,params,files=file,cookies=cookies)
            print(web.json())

# %%
obj=package()

# %%
file_size,chunks=obj.preprocess_infor_file(path,512)

# %%
obj.upload_by_batch(path,'合同.docx','合同.docx',chunks,512,file_size)
# Out:
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}
# {'status': True}

# %%
url='http://127.0.0.1:8000/Net_disk_api/token'
data={'usrName':  'test_account'}
web=requests.get(url,data)
web.json()
# Out:
# {'status': True, 'token': '83643a15c043c63659b3a4221b221cc6'}

# %%
cookies = requests.utils.dict_from_cookiejar(web.cookies)
print(cookies)
# Out:
# {'token': '83643a15c043c63659b3a4221b221cc6'}

# %%
url_download='http://127.0.0.1:8000/Net_disk_api/download'
data={'path':'合同.docx'}
web=requests.get(url_download,data,cookies=cookies)

# %%
web.text
# Out:
# 'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00ߤ�lZ\x01\x00\x00 \x05\x00\x00\x13\x00\x08\x02[Content_Types].xml �\x04\x02(����n�0\x10E���\x0f��Ub袪*\x02�>�-R�\x07\x18{\x02V��Ǽ��\x13\x02QU\x01�\nl"%3��3Vƃ�ښl\t\x11�w%�\x17=���^i7+���-\x7fd\x19&�0�A�6�l4��\x19L6\x010#�Ò�S\nO����\x15X�\x00�*��V$z�3\x1e��\x163����\x03��%p)O�\x07\x1b\x0e^�\x12\x0b���5}nH"\x18d�s�Xg�L�`�\x14��|�ԟ�|�P�rۃs\x1d��\x1a\x18?�PW�\x07�t\x1ft4Q+��"�wa���|T\\y���,N�\x1c��U�%���-D/\x01��ܚ��X�ݞ�(\x07��\x01�<E��\x1d\x0f)��\x1a\x00;�N�\x15L?�F�˼\x13��܉�\x1a�<Fk�\t�h\x03�y����ڜ���q�\x01i��?�ޯl��i�\x001��\x7f]�H�g�\x07�m�@\x1d����m�\x03\x00\x00��\x03\x00PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\x1e�\x1a��\x00\x00\x00N\x02\x00\x00\x0b\x00\x08\x02_rels/.rels �\x04\x02(� ...

# %%
web.content
# Out:
# b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\xdf\xa4\xd2lZ\x01\x00\x00 \x05\x00\x00\x13\x00\x08\x02[Content_Types].xml \xa2\x04\x02(n\xc20\x10E\xf7\x95\xfa\x0f\x91\xb7Ub\xe8\xa2\xaa*\x02\x8b>\x96-R\xe9\x07\x18{\x02V\xfd\x92\xc7\xbc\xfe\xbe\x13\x02QU\x01\x91\nl"%3\xf7\xde3V\xc6\x83\xd1\xda\x9al\t\x11\xb5w%\xeb\x17=\x96\x81\x93^i7+\xd9\xd7\xe4-\x7fd\x19&\xe1\x940\xdeA\xc96\x80l4\xbc\xbd\x19L6\x010#\xb5\xc3\x92\xcdS\nO\x9c\xa3\x9c\x83\x15X\xf8\x00\x8e*\x95\x8fV$z\x8d3\x1e\x84\xfc\x163\xe0\xf7\xbd\xde\x03\x97\xde%p)O\xb5\x07\x1b\x0e^\xa0\x12\x0b\x93\xb2\xd75}nH"\x18d\xd9s\xd3Xg\x95L\x84`\xb4\x14\x89\xea|\xe9\xd4\x9f\x94|\x97P\x90r\xdb\x83s\x1d\xf0\x8e\x1a\x18?\x98PW\x8e\x07\xect\x1ft4Q+\xc8\xc6"\xa6wa\xa9\x8b\xaf|T\\y\xb9\xb0\xa4,N\xdb\x1c\xe0\xf4U\xa5%\xb4\xfa\xda-D/\x01\x91\xce\xdc\x9a\xa2\xadX\xa1\xdd\x9e\xff(\x07\xa6\x8d\x01\xbc<E\xe3\xdb\x1d\x0f)\x91\xe0\x1a\x00;\xe7N\x84\x15L?\xafF\xf1\xcb\xbc\x13\xa4\xa2\xdc\x89\x98\x1a\xb8<Fk\xdd\t\x91h\x03\xa1y\xf6\xcf\xe6\xd8\xda\x9c\x8a\xa4\xceq\xf4\x01i\xa3\xe3?\xc6\xde\xafl\xad\xcei\xe0\x001\xe9\xd3\x7f]\x9bH\xd6g\xcf\x07\xf5m\xa0@\x1d\xc8\xe6\xdb\xfbm\xf8\x03\x00\x00\xff\xff\x03\x00PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\x1e\x91\x1a\xb7\xef\x00\x00\x00N\x02\x00\x00\x0b\x00\x08\x02_rels/.rels \xa2\x04\x02(\x0 ...

# %%
with open('../../test.docx','wb') as f:
    f.write(web.content)
    
f.close()

# %%
web.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-19-1c9212d0777a> in <module>
# ----> 1 web.json()
#
# c:\users\root\appdata\python\python37\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# c:\users\root\appdata\python\python37\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# c:\users\root\appdata\python\python37\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\users\root\appdata\python\python37\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
web.headers['Content-Disposition'].encode()
# Out:
# b'=?utf-8?b?YXR0YWNobWVudDtmaWxlbmFtZT0i5ZCI5ZCMLmRvY3gi?='

# %%
url_download='http://127.0.0.1:8000/Net_disk_api/tree'
data={'path':'tkkk'}
web=requests.get(url_download,data,cookies=cookies)

# %%
web.json()
# Out:
# {'files_infor': [{'file_name': 'test',
#    'extend_name': '.docx',
#    'file_size': 16775,
#    'last_visit': 1594821356.0306962,
#    'last_change': 1594821356.0306962},
#   {'file_name': 'test',
#    'extend_name': '.pdf',
#    'file_size': 261453,
#    'last_visit': 1594821146.68053,
#    'last_change': 1594821146.68053},
#   {'file_name': '合同',
#    'extend_name': '.docx',
#    'file_size': 16775,
#    'last_visit': 1594825236.1864283,
#    'last_change': 1594825236.1864283}],
#  'subdirecs': ['chache']}
